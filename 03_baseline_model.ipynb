# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

plt.style.use("ggplot")

processed_df = pd.read_csv("raw_data/cleaned_data.csv")



split_idx = int(len(processed_df) * 0.96)

X = processed_df.drop(columns=["ClosePrice"])
y = processed_df["ClosePrice"]

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]


# nan_counts = X_train.isna().sum()
# print(nan_counts)

model = LinearRegression()
model.fit(X_train, y_train)

print(f"Training features shape: {X_train.shape}")
print(f"Testing features shape: {X_test.shape}")
# Out:
# Training features shape: (266175, 1111)
# Testing features shape: (11091, 1111)

# %%
# baseline scores 

from sklearn.metrics import r2_score

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print("--- Baseline Model Evaluation ---")
print(f"Training R² Score: {r2_train:.4f}")
print(f"Testing R² Score:  {r2_test:.4f}")
# Out:
# --- Baseline Model Evaluation ---
# Training R² Score: 0.7779
# Testing R² Score:  0.7926
